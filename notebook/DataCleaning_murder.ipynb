# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data= pd.read_csv('../data/Murder_victim_age_sex.csv')
data.head()
# Out:
#                    Area_Name  Year               Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1             Andhra Pradesh  2001  Murder - Female Victims
# 2          Arunachal Pradesh  2001  Murder - Female Victims
# 3                      Assam  2001  Murder - Female Victims
# 4                      Bihar  2001  Murder - Female Victims
#
#       Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0  2. Female Victims                   NaN              6
# 1  2. Female Victims                  67.0            607
# 2  2. Female Victims                   2.0             16
# 3  2. Female Victims                  11.0            128
# 4  2. Female Victims                  12.0            366
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     NaN                  NaN                     NaN
# 1                    15.0                 38.0                    43.0
# ...

# %%
data.shape
# Out:
# (1018, 11)

# %%
data.info
# Out:
# <bound method DataFrame.info of                       Area_Name  Year               Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1                Andhra Pradesh  2001  Murder - Female Victims
# 2             Arunachal Pradesh  2001  Murder - Female Victims
# 3                         Assam  2001  Murder - Female Victims
# 4                         Bihar  2001  Murder - Female Victims
# ...                         ...   ...                      ...
# 1013                 Tamil Nadu  2010   Murder - Total Victims
# 1014                    Tripura  2010   Murder - Total Victims
# 1015              Uttar Pradesh  2010   Murder - Total Victims
# 1016                Uttarakhand  2010   Murder - Total Victims
# 1017                West Bengal  2010   Murder - Total Victims
#
#          Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0     2. Female Victims                   NaN              6
# ...

# %%
data.isnull().sum()
# Out:
# Area_Name                   0
# Year                        0
# Group_Name                  0
# Sub_Group_Name              0
# Victims_Above_50_Yrs       56
# Victims_Total               0
# Victims_Upto_10_15_Yrs    142
# Victims_Upto_10_Yrs       118
# Victims_Upto_15_18_Yrs    130
# Victims_Upto_18_30_Yrs      9
# Victims_Upto_30_50_Yrs     11
# dtype: int64

# %%
data.drop(["Group_Name"],axis = 1, inplace = True)
data.head()
# Out:
#                    Area_Name  Year     Sub_Group_Name  Victims_Above_50_Yrs  \
# 0  Andaman & Nicobar Islands  2001  2. Female Victims                   NaN
# 1             Andhra Pradesh  2001  2. Female Victims                  67.0
# 2          Arunachal Pradesh  2001  2. Female Victims                   2.0
# 3                      Assam  2001  2. Female Victims                  11.0
# 4                      Bihar  2001  2. Female Victims                  12.0
#
#    Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0              6                     NaN                  NaN
# 1            607                    15.0                 38.0
# 2             16                     0.0                  0.0
# 3            128                     8.0                  4.0
# 4            366                     0.0                  0.0
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# ...

# %%
data.shape
# Out:
# (1018, 10)

# %%
fin_data = data[data["Sub_Group_Name"]!="3. Total"]
fin_data.head()
# Out:
#                    Area_Name  Year     Sub_Group_Name  Victims_Above_50_Yrs  \
# 0  Andaman & Nicobar Islands  2001  2. Female Victims                   NaN
# 1             Andhra Pradesh  2001  2. Female Victims                  67.0
# 2          Arunachal Pradesh  2001  2. Female Victims                   2.0
# 3                      Assam  2001  2. Female Victims                  11.0
# 4                      Bihar  2001  2. Female Victims                  12.0
#
#    Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0              6                     NaN                  NaN
# 1            607                    15.0                 38.0
# 2             16                     0.0                  0.0
# 3            128                     8.0                  4.0
# 4            366                     0.0                  0.0
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# ...

# %%
fin_data.shape
# Out:
# (676, 10)

# %%
fin_data=fin_data.fillna(0)
fin_data.head()
# Out:
#                    Area_Name  Year     Sub_Group_Name  Victims_Above_50_Yrs  \
# 0  Andaman & Nicobar Islands  2001  2. Female Victims                   0.0
# 1             Andhra Pradesh  2001  2. Female Victims                  67.0
# 2          Arunachal Pradesh  2001  2. Female Victims                   2.0
# 3                      Assam  2001  2. Female Victims                  11.0
# 4                      Bihar  2001  2. Female Victims                  12.0
#
#    Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0              6                     0.0                  0.0
# 1            607                    15.0                 38.0
# 2             16                     0.0                  0.0
# 3            128                     8.0                  4.0
# 4            366                     0.0                  0.0
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# ...

# %%
datakeys=['Area_Name','Sub_Group_Name']
for i in datakeys:
    print(i, fin_data[i].unique())
# Out:
# Area_Name ['Andaman & Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh' 'Assam'
#  'Bihar' 'Chandigarh' 'Chhattisgarh' 'Delhi' 'Goa' 'Gujarat' 'Haryana'
#  'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand' 'Karnataka' 'Kerala'
#  'Lakshadweep' 'Madhya Pradesh' 'Maharashtra' 'Manipur' 'Meghalaya'
#  'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab' 'Rajasthan' 'Sikkim'
#  'Tamil Nadu' 'Tripura' 'Uttar Pradesh' 'Uttarakhand' 'West Bengal'
#  'Dadra & Nagar Haveli' 'Daman & Diu']
# Sub_Group_Name ['2. Female Victims' '1. Male Victims']

# %%
from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
for i in datakeys:
    fin_data[i]=a.fit_transform(fin_data[i])
fin_data.head()
# Out:
#    Area_Name  Year  Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0          0  2001               1                   0.0              6
# 1          1  2001               1                  67.0            607
# 2          2  2001               1                   2.0             16
# 3          3  2001               1                  11.0            128
# 4          4  2001               1                  12.0            366
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     0.0                  0.0                     0.0
# 1                    15.0                 38.0                    43.0
# 2                     0.0                  0.0                     0.0
# 3                     8.0                  4.0                    23.0
# 4                     0.0                  0.0                    40.0
#
#    Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# 0                     4.0                     2.0
# ...

# %%
fin_data.to_csv("../data/final_murderdataset.csv")
